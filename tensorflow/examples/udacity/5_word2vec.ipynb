# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
[reverse_dictionary[a] for a in data[:10]]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against']

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)

  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)

  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

batch_size = 8

print('data:', [reverse_dictionary[di] for di in data[:batch_size]])

for num_skips, skip_window in [(1, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=batch_size, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(batch_size)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 1 and skip_window = 1:
#     batch: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#     labels: ['as', 'originated', 'term', 'of', 'abuse', 'first', 'abuse', 'against']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'term', 'anarchism', 'as', 'term', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
#with graph.as_default(), tf.device('/gpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)


  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))

  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
  
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))
    

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm

  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)    
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0

  for step in range(num_steps):
    
    batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}    
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    
    average_loss += l
    
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
            
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.018484
# Nearest to all: lavos, rollout, quay, nestorianism, stint, jabberwock, accidents, lublin,
# Nearest to or: une, cdma, multiprogramming, detects, forgive, choked, upsilon, classifying,
# Nearest to which: nu, woodstock, istv, clich, reich, restaurant, dualistic, deuterostomes,
# Nearest to more: adjacency, rideau, drinkers, cali, vernon, pot, mannerheim, loosened,
# Nearest to from: greatness, dumped, handicap, satiric, rockstar, attainment, tamers, rebel,
# Nearest to s: differentials, antiretroviral, zelda, capricious, transmitters, luxury, italo, wtc,
# Nearest to have: batll, helpers, therus, jis, divisible, electoral, veronica, sparrows,
# Nearest to new: embellishment, famine, yarns, attest, vassals, computing, undermined, larp,
# Nearest to world: lindbergh, moines, trader, chipmunk, mackenzie, gentler, applets, firefighting,
# Nearest to be: bangla, suspense, gays, fails, shadowy, admirer, appropriately, danube,
# Nearest to seven: subjectivity, octahedron, shameful, pun, coprime, beanstalk, mia, tails,
# Nearest to used: mammary, hanssen, gascony, gourd, sidewalk, wahhabis, rebranded, grandchildren,
# Nearest to can: sandwiched, gauntlet, pacts, polyphonic, homophobia, maximization, emulators, stepfather,
# Nearest to other: tara, nsted, enchanter, mcdaniel, paladins, seminal, inscriptions, mates,
# Nearest to also: ben, khaled, vanadium, stratum, ontario, quotient, op, fires,
# Nearest to been: exercising, vesuvius, bernard, king, uomo, entailed, contradiction, cytotoxic,
# Average loss at step 2000: 4.364119
# Average loss at step 4000: 3.866185
# Average loss at step 6000: 3.790586
# Average loss at step 8000: 3.681843
# Average loss at step 10000: 3.608250
# Nearest to all: danneskj, some, anhalt, lunch, engravings, miranda, nd, average,
# Nearest to or: and, universes, glyphs, superorder, classifying, lava, sulaiman, near,
# Nearest to which: that, this, also, who, dualistic, istv, ulysses, goose,
# Nearest to more: visas, very, wolfhounds, less, retaken, contradicted, mare, woodrow,
# Nearest to from: in, like, continent, on, during, carbines, to, dispense,
# Nearest to s: his, drury, mjd, disallowed, drc, conspirator, and, presaged,
# Nearest to have: had, be, has, ucr, are, were, kinsella, include,
# Nearest to new: engl, scientific, corsican, embellishment, crafty, urbana, declining, gamblers,
# Nearest to world: lindbergh, trader, repent, frosts, tanistry, stair, gifs, pluto,
# Nearest to be: have, bangla, according, suspense, canonical, downwind, was, genji,
# Nearest to seven: eight, six, five, nine, three, four, zero, two,
# Nearest to used: gascony, gg, unaware, known, mammary, itis, handoff, hanssen,
# Nearest to can: will, would, may, woodson, godless, gauntlet, should, armand,
# Nearest to other: different, splicing, many, some, phyla, learn, sho, buffett,
# Nearest to also: often, which, not, who, he, it, vomiting, penang,
# Nearest to been: vesuvius, entailed, be, incandescent, by, enciphered, pretending, refering,
# Average loss at step 12000: 3.599819
# Average loss at step 14000: 3.566928
# Average loss at step 16000: 3.405547
# Average loss at step 18000: 3.456049
# Average loss at step 20000: 3.541346
# Nearest to all: some, many, several, billionaire, these, walk, parametric, madhu,
# Nearest to or: and, universes, than, sulaiman, impinging, licensees, rantissi, fournier,
# Nearest to which: that, this, also, who, it, there, but, often,
# Nearest to more: less, very, most, zut, weaken, woodrow, profane, clinics,
# Nearest to from: in, into, during, at, like, through, schmitz, shop,
# Nearest to s: luxury, antipodes, locomotion, fogo, gamespy, alto, ugly, jeremy,
# Nearest to have: has, had, be, were, are, offensively, ucr, include,
# Nearest to new: corsican, scientific, crafty, embellishment, ghost, hotter, fermion, microscopes,
# Nearest to world: lindbergh, tanistry, repent, trader, frosts, snowboarding, stair, fortunes,
# Nearest to be: have, by, was, been, were, is, bangla, according,
# Nearest to seven: eight, six, nine, five, four, three, two, zero,
# Nearest to used: known, gascony, unaware, gg, hanssen, genoese, pete, sidewalk,
# Nearest to can: may, will, would, should, could, woodson, must, might,
# Nearest to other: many, some, different, thee, splicing, polytechnical, several, proliferate,
# Nearest to also: which, often, who, not, still, sometimes, it, always,
# Nearest to been: be, entailed, were, always, had, by, become, was,
# Average loss at step 22000: 3.504182
# Average loss at step 24000: 3.487802
# Average loss at step 26000: 3.482574
# Average loss at step 28000: 3.482283
# Average loss at step 30000: 3.496985
# Nearest to all: some, these, many, xia, laughter, several, lost, hydrology,
# Nearest to or: and, connelly, but, licensees, foonly, universes, talisman, karaites,
# Nearest to which: this, that, but, also, it, where, however, what,
# Nearest to more: less, very, most, weaken, greater, clinics, visas, profane,
# Nearest to from: into, on, through, decadence, precludes, across, during, peaceful,
# Nearest to s: his, luxury, antipodes, sud, stupidity, mjd, emb, esterification,
# Nearest to have: had, has, were, are, be, include, downloads, offensively,
# Nearest to new: scientific, corsican, hotter, higher, albers, gamblers, propeller, microscopes,
# Nearest to world: tanistry, repent, lindbergh, country, counterculture, snowboarding, frosts, fortunes,
# Nearest to be: have, been, were, is, become, downwind, according, tattoo,
# Nearest to seven: eight, five, four, nine, three, six, zero, two,
# Nearest to used: known, accepted, gascony, unaware, gg, unter, mcpherson, found,
# Nearest to can: may, would, will, could, should, must, might, cannot,
# Nearest to other: thee, some, sho, different, basset, many, several, tolvaj,
# Nearest to also: often, sometimes, still, which, now, it, who, always,
# Nearest to been: become, were, be, always, had, was, bipedal, already,
# Average loss at step 32000: 3.499028
# Average loss at step 34000: 3.491384
# Average loss at step 36000: 3.458898
# Average loss at step 38000: 3.300048
# Average loss at step 40000: 3.430021
# Nearest to all: some, many, these, several, mound, xia, those, lost,
# Nearest to or: and, than, callahan, japonic, promotional, wwe, any, universes,
# Nearest to which: this, that, often, also, usually, but, who, it,
# Nearest to more: less, most, very, greater, smaller, profane, higher, miskelley,
# Nearest to from: into, on, for, across, like, in, over, shop,
# Nearest to s: his, jacinto, dharmas, salle, sud, scan, canal, fawcett,
# Nearest to have: has, had, were, be, include, are, downloads, cigar,
# Nearest to new: corsican, scientific, mon, microscopes, prepare, albers, gamblers, bangla,
# Nearest to world: tanistry, repent, lindbergh, u, snowboarding, harwich, bituminous, gentiles,
# Nearest to be: have, been, was, being, is, downwind, were, are,
# Nearest to seven: six, eight, nine, five, four, three, two, zero,
# Nearest to used: known, found, accepted, considered, able, referred, gascony, spoken,
# Nearest to can: may, will, would, could, should, must, might, cannot,
# Nearest to other: different, thee, some, many, splicing, goa, treblinka, basset,
# Nearest to also: often, still, which, sometimes, who, always, now, usually,
# Nearest to been: become, was, be, were, already, papyri, bipedal, always,
# Average loss at step 42000: 3.433431
# Average loss at step 44000: 3.451687
# Average loss at step 46000: 3.448216
# Average loss at step 48000: 3.357906
# Average loss at step 50000: 3.382067
# Nearest to all: xia, many, these, anhalt, mound, reviews, lost, admirals,
# Nearest to or: and, than, endeavors, accented, like, unfashionable, but, any,
# Nearest to which: this, that, also, who, often, usually, still, these,
# Nearest to more: less, most, very, greater, smaller, higher, clinics, profane,
# Nearest to from: into, across, in, during, shop, on, through, schmitz,
# Nearest to s: sud, stupidity, fawcett, sacrificial, brass, motor, whose, molyneux,
# Nearest to have: had, has, were, be, are, include, weigh, ucr,
# Nearest to new: albers, scientific, corsican, single, fmri, gamblers, timberlake, layer,
# Nearest to world: tanistry, repent, lindbergh, snowboarding, gentiles, nas, u, bituminous,
# Nearest to be: have, become, been, was, were, being, is, downwind,
# Nearest to seven: six, nine, eight, four, five, three, zero, one,
# Nearest to used: known, referred, written, accepted, described, found, considered, spoken,
# Nearest to can: will, may, would, could, must, should, cannot, might,
# Nearest to other: different, various, thee, some, many, several, daigo, concluding,
# Nearest to also: often, still, which, sometimes, who, now, geometric, romanov,
# Nearest to been: become, be, were, already, papyri, was, bipedal, hutchison,
# Average loss at step 52000: 3.437180
# Average loss at step 54000: 3.426122
# Average loss at step 56000: 3.438749
# Average loss at step 58000: 3.395965
# Average loss at step 60000: 3.393150
# Nearest to all: many, these, those, some, various, intervention, both, xia,
# Nearest to or: and, than, like, unfashionable, laminal, thule, endeavors, libretto,
# Nearest to which: that, this, what, usually, often, these, however, destroyer,
# Nearest to more: less, most, greater, very, clinics, smaller, higher, profane,
# Nearest to from: into, through, across, in, within, nsted, forming, hangings,
# Nearest to s: luxury, validation, sud, stupidity, roller, formative, alto, emulator,
# Nearest to have: has, had, include, were, are, offensively, be, downloads,
# Nearest to new: albers, corsican, microscopes, scientific, previous, forecast, prepare, evaluate,
# Nearest to world: repent, bituminous, lindbergh, gentiles, tanistry, snowboarding, nashville, u,
# Nearest to be: been, become, was, are, have, is, downwind, being,
# Nearest to seven: eight, four, six, nine, five, three, zero, two,
# Nearest to used: known, referred, written, considered, described, accepted, found, spoken,
# Nearest to can: may, will, would, could, should, must, cannot, might,
# Nearest to other: various, different, many, several, including, daigo, merry, splicing,
# Nearest to also: often, still, now, sometimes, below, mycenae, usually, never,
# Nearest to been: become, be, already, were, had, bipedal, was, hutchison,
# Average loss at step 62000: 3.238082
# Average loss at step 64000: 3.259699
# Average loss at step 66000: 3.404432
# Average loss at step 68000: 3.395785
# Average loss at step 70000: 3.358693
# Nearest to all: many, some, several, various, each, both, those, these,
# Nearest to or: and, than, while, any, but, accented, paracompact, like,
# Nearest to which: that, this, what, usually, also, but, these, often,
# Nearest to more: less, most, very, higher, extremely, couplet, smaller, greater,
# Nearest to from: across, through, into, forming, overdue, decadence, carbines, within,
# Nearest to s: emb, stupidity, isbn, sacrum, whose, salle, alto, validation,
# Nearest to have: had, has, were, include, are, downloads, be, tend,
# Nearest to new: corsican, previous, scientific, albers, standoff, cadre, microscopes, lymphedema,
# Nearest to world: u, repent, lindbergh, snowboarding, tanistry, gentiles, walpole, haka,
# Nearest to be: been, become, was, being, were, is, have, are,
# Nearest to seven: six, eight, four, nine, five, three, two, one,
# Nearest to used: known, described, written, seen, referred, regarded, found, considered,
# Nearest to can: may, could, would, will, should, must, cannot, might,
# Nearest to other: various, different, including, many, some, daigo, merry, capability,
# Nearest to also: still, often, now, which, sometimes, usually, never, commonly,
# Nearest to been: become, be, was, recently, were, already, had, remained,
# Average loss at step 72000: 3.372069
# Average loss at step 74000: 3.344640
# Average loss at step 76000: 3.319814
# Average loss at step 78000: 3.353641
# Average loss at step 80000: 3.378294
# Nearest to all: both, many, several, each, every, various, these, hoosier,
# Nearest to or: and, while, than, but, kwahu, with, com, endeavors,
# Nearest to which: that, this, what, usually, also, typically, often, based,
# Nearest to more: less, most, very, higher, greater, extremely, quite, smaller,
# Nearest to from: across, into, through, in, overdue, after, against, before,
# Nearest to s: validation, semiotics, aerospace, hydrocarbon, mediaeval, whose, lee, stupidity,
# Nearest to have: had, has, are, include, were, be, downloads, having,
# Nearest to new: previous, corsican, cadre, university, loeb, nurtured, amalgamated, standoff,
# Nearest to world: repent, u, snowboarding, counterculture, lindbergh, menabrea, nicknames, tanistry,
# Nearest to be: been, being, have, become, is, was, were, easily,
# Nearest to seven: eight, six, nine, five, four, three, zero, one,
# Nearest to used: known, referred, described, seen, considered, written, available, applied,
# Nearest to can: may, could, will, would, cannot, must, should, might,
# Nearest to other: various, including, many, thee, individual, krahn, western, chases,
# Nearest to also: still, often, now, sometimes, never, actually, below, which,
# Nearest to been: become, be, recently, had, was, were, remained, occurred,
# Average loss at step 82000: 3.401114
# Average loss at step 84000: 3.408628
# Average loss at step 86000: 3.389478
# Average loss at step 88000: 3.349853
# Average loss at step 90000: 3.365397
# Nearest to all: many, both, several, these, some, various, each, intervention,
# Nearest to or: and, autopsy, rocking, whereas, than, callahan, adopt, landholders,
# Nearest to which: this, that, what, usually, also, but, who, typically,
# Nearest to more: less, very, most, greater, extremely, quite, higher, smaller,
# Nearest to from: across, through, into, within, during, onto, overdue, in,
# Nearest to s: whose, sud, isbn, stupidity, his, homogeneity, gestation, discards,
# Nearest to have: had, has, were, are, include, be, downloads, having,
# Nearest to new: corsican, previous, standoff, different, nurtured, separate, cadre, apollodorus,
# Nearest to world: repent, fortunes, nicknames, reproducible, haka, snowboarding, address, gentiles,
# Nearest to be: been, become, have, is, being, was, easily, remain,
# Nearest to seven: eight, four, nine, six, five, three, one, zero,
# Nearest to used: referred, known, applied, described, considered, seen, designed, called,
# Nearest to can: could, may, will, would, must, cannot, should, might,
# Nearest to other: various, individual, including, krahn, capability, merry, different, cannae,
# Nearest to also: still, often, now, sometimes, actually, which, never, always,
# Nearest to been: become, be, was, already, recently, remained, were, previously,
# Average loss at step 92000: 3.394262
# Average loss at step 94000: 3.255461
# Average loss at step 96000: 3.354141
# Average loss at step 98000: 3.245691
# Average loss at step 100000: 3.353240
# Nearest to all: many, these, several, various, both, every, some, any,
# Nearest to or: and, than, thule, per, while, terraforming, nene, anatomically,
# Nearest to which: that, this, usually, typically, what, hawthorne, but, actually,
# Nearest to more: less, most, very, greater, extremely, quite, higher, longer,
# Nearest to from: into, across, in, through, within, corrects, at, onto,
# Nearest to s: his, whose, presaged, isbn, her, alberto, the, sud,
# Nearest to have: had, has, include, were, are, be, tend, downloads,
# Nearest to new: separate, corsican, different, previous, preferring, cadre, specific, albers,
# Nearest to world: fortunes, repent, nicknames, reproducible, u, country, snowboarding, address,
# Nearest to be: been, have, become, easily, is, being, are, refer,
# Nearest to seven: eight, nine, six, four, five, three, zero, two,
# Nearest to used: referred, known, applied, designed, considered, seen, found, held,
# Nearest to can: could, may, must, will, would, cannot, should, might,
# Nearest to other: various, individual, others, including, aristocratic, maduro, different, swordsmiths,
# Nearest to also: still, now, sometimes, actually, often, never, usually, normally,
# Nearest to been: become, be, already, recently, remained, argentines, was, ever,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

#with graph.as_default(), tf.device('/cpu:0'):
with graph.as_default(): #, tf.device('/gpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)


  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))

  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
  
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))
    

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm

  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)    
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0

  for step in range(num_steps):
    
    #batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}    
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    
    average_loss += l
    
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
            
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.220825
# Nearest to been: kristina, ducas, hateful, misunderstandings, bitten, cubism, transports, gee,
# Nearest to only: brubaker, acadian, hound, adjustable, musik, upu, thematically, cephalon,
# Nearest to of: intersects, ideology, orbits, stwa, palladius, detained, feudal, gerda,
# Nearest to are: journalism, zapatistas, coastline, nnhilde, hst, seminary, thank, yours,
# Nearest to about: shires, hades, invite, enforcement, remainder, partly, guru, mustang,
# Nearest to to: randori, pelagius, antonym, intimidate, amiens, unethical, pravda, gprs,
# Nearest to have: lago, bro, rationale, compostela, vehicular, abide, steamboat, jujutsu,
# Nearest to they: superior, mansi, reneged, attorneys, banting, rwanda, tutored, dry,
# Nearest to was: cumann, diefenbaker, bengali, boney, chlorine, sale, spratly, together,
# Nearest to may: dee, bibles, suburbs, vs, tuba, penzance, compressors, harem,
# Nearest to for: plunder, quintessence, majlis, cke, naur, generalize, cbd, idolatrous,
# Nearest to history: buzzard, frederick, avril, imparting, gg, migrated, keystone, tobit,
# Nearest to b: receive, sprung, taggart, peppers, kowloon, crowd, inferno, affirmation,
# Nearest to five: thermionic, coursing, alda, carp, ounce, hdtv, alshehhi, intercept,
# Nearest to a: mjt, played, offenbach, unregulated, readiness, bomis, anomalous, hinds,
# Nearest to its: navigator, language, nee, hunchback, myron, undertones, uninterested, hera,
# Average loss at step 2000: 4.364276
# Average loss at step 4000: 3.860045
# Average loss at step 6000: 3.785692
# Average loss at step 8000: 3.685352
# Average loss at step 10000: 3.617077
# Nearest to been: be, hermitian, ducas, was, hateful, alone, cubism, combinatorics,
# Nearest to only: thematically, quieter, adjustable, unabridged, hanks, cephalon, ferdinand, upu,
# Nearest to of: in, chickasaw, nac, medalists, dosages, for, at, and,
# Nearest to are: were, is, have, banjo, was, kenji, rakis, polygons,
# Nearest to about: lightning, hades, approved, bombarding, invite, shires, yellowish, bystanders,
# Nearest to to: would, pelagius, sybase, unethical, pravda, mixer, horn, goi,
# Nearest to have: had, has, be, were, are, make, lago, having,
# Nearest to they: he, it, not, she, powerpoint, blackstone, there, who,
# Nearest to was: is, had, were, has, by, together, happier, be,
# Nearest to may: can, penzance, osman, dod, could, bibles, vs, suburbs,
# Nearest to for: ballerina, in, alpine, cirth, with, evangelium, from, of,
# Nearest to history: buzzard, doctrine, pickled, inner, frederick, lucille, laced, tobit,
# Nearest to b: d, taggart, weakest, receive, thorne, inferno, crowd, concurrent,
# Nearest to five: six, three, seven, eight, four, nine, two, zero,
# Nearest to a: the, pedophilia, histoire, nikos, actuarial, coasts, ral, ust,
# Nearest to its: the, his, their, navigator, hottest, tiberian, hunchback, kare,
# Average loss at step 12000: 3.598944
# Average loss at step 14000: 3.563931
# Average loss at step 16000: 3.406014
# Average loss at step 18000: 3.460979
# Average loss at step 20000: 3.534606
# Nearest to been: be, become, was, were, never, hermitian, cubism, gentoo,
# Nearest to only: always, unabridged, thematically, adopted, leni, erv, ferdinand, but,
# Nearest to of: urging, nac, at, chickasaw, in, same, for, during,
# Nearest to are: were, is, have, kenji, ashkenazi, viscount, other, was,
# Nearest to about: approved, christophe, lightning, bombarding, yellowish, lcds, std, shires,
# Nearest to to: would, pelagius, may, will, unethical, not, can, gprs,
# Nearest to have: had, has, were, are, be, having, make, absolutism,
# Nearest to they: he, we, there, it, not, she, who, but,
# Nearest to was: is, had, has, were, by, became, been, be,
# Nearest to may: can, would, could, must, will, to, osman, cannot,
# Nearest to for: ballerina, by, radius, with, alpine, from, dissolution, of,
# Nearest to history: consists, halves, biting, doctrine, frederick, buzzard, permanent, essays,
# Nearest to b: d, hamitic, weakest, concurrent, pharmacology, melt, microchips, j,
# Nearest to five: eight, seven, four, six, three, two, zero, nine,
# Nearest to a: this, anions, actuarial, volo, chiropractors, saltpeter, the, francophones,
# Nearest to its: their, his, the, this, them, egerton, these, hardships,
# Average loss at step 22000: 3.501880
# Average loss at step 24000: 3.486766
# Average loss at step 26000: 3.482141
# Average loss at step 28000: 3.474596
# Average loss at step 30000: 3.504581
# Nearest to been: be, become, was, were, never, gentoo, hateful, had,
# Nearest to only: always, thematically, problem, alcaeus, leni, chivalrous, enchantment, going,
# Nearest to of: in, from, nac, ces, and, for, itt, reinventing,
# Nearest to are: were, is, have, those, include, be, these, kenji,
# Nearest to about: farrar, approved, christophe, lightning, yellowish, lcds, peacefully, levite,
# Nearest to to: would, will, can, cannot, must, may, not, pelagius,
# Nearest to have: had, has, were, are, be, having, franchising, make,
# Nearest to they: there, we, he, it, who, not, you, she,
# Nearest to was: is, had, were, has, became, been, when, cede,
# Nearest to may: can, would, must, could, will, might, cannot, should,
# Nearest to for: with, eileen, ibrd, of, if, scientific, mjf, as,
# Nearest to history: halves, biting, consists, doctrine, burks, collection, debris, casings,
# Nearest to b: d, hamitic, avec, esau, chaosium, weakest, st, backyard,
# Nearest to five: four, eight, seven, six, three, two, nine, zero,
# Nearest to a: actuarial, any, no, nicodemus, the, discreetly, habilitation, anomalous,
# Nearest to its: their, his, the, stabilize, her, failing, randomness, edd,
# Average loss at step 32000: 3.502506
# Average loss at step 34000: 3.495182
# Average loss at step 36000: 3.449529
# Average loss at step 38000: 3.300404
# Average loss at step 40000: 3.432144
# Nearest to been: become, be, was, gentoo, never, were, had, being,
# Nearest to only: always, enchantment, stalling, signifying, leni, tonight, consistory, suppressing,
# Nearest to of: in, gematria, dosages, for, interceptions, nac, original, mihdhar,
# Nearest to are: were, have, is, but, those, be, include, aznar,
# Nearest to about: farrar, levite, lightning, christophe, std, lcds, yellowish, over,
# Nearest to to: could, can, must, sybase, pelagius, quadrant, may, univac,
# Nearest to have: had, has, were, are, be, franchising, infamy, include,
# Nearest to they: we, there, he, she, it, you, these, who,
# Nearest to was: is, had, were, has, became, been, be, when,
# Nearest to may: can, would, must, will, could, cannot, might, should,
# Nearest to for: in, if, ballerina, linea, clones, of, from, augustan,
# Nearest to history: halves, portion, biting, consists, burks, cappella, oxidized, doctrine,
# Nearest to b: d, hamitic, c, r, UNK, sibyl, j, gpcrs,
# Nearest to five: seven, six, three, eight, four, nine, two, zero,
# Nearest to a: the, tuck, actuarial, alexandra, or, another, erasmus, volo,
# Nearest to its: their, his, the, her, galleries, them, whose, gash,
# Average loss at step 42000: 3.433462
# Average loss at step 44000: 3.453191
# Average loss at step 46000: 3.453979
# Average loss at step 48000: 3.352750
# Average loss at step 50000: 3.379157
# Nearest to been: become, be, was, were, researchers, suffered, gentoo, always,
# Nearest to only: always, tonight, enchantment, preposition, roofed, murderers, dw, mda,
# Nearest to of: moussa, and, in, strictest, marxian, confederates, lbs, include,
# Nearest to are: were, is, have, although, those, these, sparrows, be,
# Nearest to about: farrar, levite, christophe, std, peacefully, over, mamma, lightning,
# Nearest to to: would, anson, cannot, wye, can, will, dunst, themed,
# Nearest to have: had, has, were, be, are, having, include, forster,
# Nearest to they: we, he, there, she, it, you, these, who,
# Nearest to was: is, has, were, became, had, be, been, by,
# Nearest to may: can, would, must, will, could, should, might, cannot,
# Nearest to for: chola, including, ibrd, after, conversant, clones, operationally, microclimates,
# Nearest to history: portion, halves, biting, consists, list, burks, oceanography, thousands,
# Nearest to b: d, c, r, f, sibyl, splinter, debaters, gpcrs,
# Nearest to five: four, six, eight, seven, three, zero, nine, two,
# Nearest to a: another, alexandra, the, actuarial, conjunctivitis, any, coordinate, shipwrecks,
# Nearest to its: their, his, the, her, edd, vance, galleries, recieved,
# Average loss at step 52000: 3.435977
# Average loss at step 54000: 3.422762
# Average loss at step 56000: 3.438332
# Average loss at step 58000: 3.393992
# Average loss at step 60000: 3.391908
# Nearest to been: become, be, was, had, were, gentoo, always, anisotropy,
# Nearest to only: always, usually, roofed, enchantment, leni, present, dagmar, mda,
# Nearest to of: for, in, same, entire, strictest, urging, moussa, akhenaten,
# Nearest to are: were, have, is, these, those, include, be, swallows,
# Nearest to about: farrar, over, levite, peacefully, christophe, yellowish, parsley, minutes,
# Nearest to to: sharper, for, would, sybase, not, daime, pravda, invalid,
# Nearest to have: had, has, are, were, be, having, produce, provide,
# Nearest to they: we, there, he, you, she, it, not, these,
# Nearest to was: is, had, became, were, has, been, although, when,
# Nearest to may: can, would, must, will, could, should, might, cannot,
# Nearest to for: including, of, if, without, to, ballerina, ibrd, eileen,
# Nearest to history: portion, list, biting, halves, consists, thousands, kaczynski, economy,
# Nearest to b: d, c, f, r, sibyl, structuring, y, splinter,
# Nearest to five: four, six, eight, three, seven, nine, zero, two,
# Nearest to a: the, actuarial, any, nicodemus, alexandra, danorum, no, another,
# Nearest to its: their, his, her, the, galleries, edd, whose, variste,
# Average loss at step 62000: 3.240835
# Average loss at step 64000: 3.253293
# Average loss at step 66000: 3.403336
# Average loss at step 68000: 3.394412
# Average loss at step 70000: 3.360140
# Nearest to been: become, be, was, had, were, gentoo, anisotropy, already,
# Nearest to only: enchantment, always, mda, dagmar, leni, until, managed, tonight,
# Nearest to of: including, peress, strictest, apologize, boosting, original, argus, in,
# Nearest to are: were, is, although, have, include, these, be, bbci,
# Nearest to about: farrar, over, christophe, levite, peacefully, yellowish, kodak, whatever,
# Nearest to to: will, for, would, can, must, quadrant, gprs, should,
# Nearest to have: had, has, were, having, are, be, provide, include,
# Nearest to they: we, there, he, you, it, she, who, these,
# Nearest to was: is, has, were, had, been, be, became, being,
# Nearest to may: can, would, will, must, could, should, might, cannot,
# Nearest to for: including, ballerina, without, to, after, clones, in, syst,
# Nearest to history: list, portion, biting, halves, consists, sicily, thousands, faces,
# Nearest to b: d, f, r, p, y, splinter, c, structuring,
# Nearest to five: four, six, eight, seven, three, zero, nine, two,
# Nearest to a: the, volo, alexandra, actuarial, spit, conjunctivitis, tinker, another,
# Nearest to its: their, his, the, her, recieved, whose, our, axes,
# Average loss at step 72000: 3.374613
# Average loss at step 74000: 3.345821
# Average loss at step 76000: 3.315372
# Average loss at step 78000: 3.353610
# Average loss at step 80000: 3.372481
# Nearest to been: become, be, was, were, begun, gentoo, had, fallen,
# Nearest to only: always, mda, last, roofed, enchantment, preposition, dagmar, first,
# Nearest to of: including, in, lbs, entire, moussa, urging, laozi, original,
# Nearest to are: were, have, include, although, is, aznar, these, flatland,
# Nearest to about: farrar, christophe, over, peacefully, levite, painting, primality, exhibiting,
# Nearest to to: mooring, will, can, would, sybase, should, gprs, must,
# Nearest to have: had, has, are, were, be, having, include, franchising,
# Nearest to they: we, he, there, you, she, it, these, who,
# Nearest to was: is, has, were, became, had, being, been, during,
# Nearest to may: can, would, could, must, will, might, should, cannot,
# Nearest to for: after, including, operationally, ballerina, torrents, without, against, ibrd,
# Nearest to history: biting, portion, list, halves, consists, cappella, faces, sicily,
# Nearest to b: d, f, c, r, p, volts, dzhokhar, sibyl,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to a: the, another, pedophilia, shaded, tuck, alexandra, actuarial, volo,
# Nearest to its: their, his, her, our, the, whose, recieved, your,
# Average loss at step 82000: 3.409917
# Average loss at step 84000: 3.409573
# Average loss at step 86000: 3.385892
# Average loss at step 88000: 3.350155
# Average loss at step 90000: 3.363023
# Nearest to been: become, be, was, already, had, begun, gentoo, fallen,
# Nearest to only: mda, even, roofed, preposition, always, dagmar, leni, equally,
# Nearest to of: including, in, for, eth, entire, marxian, multipliers, biggest,
# Nearest to are: were, is, these, have, include, although, those, bbci,
# Nearest to about: farrar, christophe, over, kodak, painting, counterparts, parsley, altaic,
# Nearest to to: gprs, would, must, will, fairer, sybase, mooring, kamenev,
# Nearest to have: had, has, were, are, having, be, include, provide,
# Nearest to they: we, he, she, there, you, it, soon, these,
# Nearest to was: is, had, were, became, has, been, be, while,
# Nearest to may: can, could, must, will, would, should, might, cannot,
# Nearest to for: including, ballerina, after, ventspils, without, chola, feral, redirected,
# Nearest to history: biting, list, portion, halves, consists, historical, event, cappella,
# Nearest to b: d, f, r, y, eduskunta, c, smyth, volts,
# Nearest to five: four, eight, six, seven, three, nine, zero, two,
# Nearest to a: actuarial, the, conjunctivitis, canmore, any, alexandra, tuck, danorum,
# Nearest to its: their, his, her, the, whose, our, your, wilcox,
# Average loss at step 92000: 3.400353
# Average loss at step 94000: 3.249777
# Average loss at step 96000: 3.355211
# Average loss at step 98000: 3.240648
# Average loss at step 100000: 3.351628
# Nearest to been: become, be, was, already, had, begun, gentoo, fallen,
# Nearest to only: mda, even, saucers, roofed, preposition, equally, still, always,
# Nearest to of: including, entire, in, lendl, moussa, chopper, original, homelands,
# Nearest to are: were, have, those, these, although, include, is, battalions,
# Nearest to about: farrar, christophe, over, kodak, levite, peacefully, counterparts, mamma,
# Nearest to to: will, should, would, must, can, could, kamenev, mooring,
# Nearest to have: had, has, were, seem, are, having, be, franchising,
# Nearest to they: we, there, he, you, she, it, i, these,
# Nearest to was: is, became, been, has, were, had, becomes, being,
# Nearest to may: can, must, could, will, should, would, might, cannot,
# Nearest to for: including, when, after, against, without, neoliberal, before, offended,
# Nearest to history: list, biting, portion, faces, science, blume, cappella, historical,
# Nearest to b: d, avec, heijenoort, diversions, hamitic, bamiyan, aaa, halmos,
# Nearest to five: seven, four, eight, six, three, two, zero, nine,
# Nearest to a: the, another, any, actuarial, tuck, alexandra, spit, volo,
# Nearest to its: their, his, the, galleries, whose, her, our, variste,

# %%
final_embeddings.shape
# Out:
# (50000, 128)

# %%
# Lets investigate what's close to things
a = np.mean([
        final_embeddings[dictionary['three']], 
        final_embeddings[dictionary['donkey']],
        final_embeddings[dictionary['nine']],
        final_embeddings[dictionary['baby']]
    ], axis=0)

def show_similar(word):
    # Get the embedding
    a = final_embeddings[dictionary[word]]

    # Calculate the difference from all the other embeddings
    diff = np.argsort(np.linalg.norm(final_embeddings-a, axis=1))
    print(",".join([reverse_dictionary[a] for a in diff[:10]]))

show_similar('million')
show_similar('it')
show_similar('g')
# Out:
# million,thousand,zero,mister,hundred,protease,estimated,elevations,grievances,billion
# it,he,she,there,this,they,mgh,which,what,actually
# g,saarinen,fiber,f,j,fl,shoal,petals,cemeteries,int

# %%
def minus_add(a, b, c):
    vec = final_embeddings[dictionary[a]] - final_embeddings[dictionary[b]] + final_embeddings[dictionary[c]]
    diff = np.argsort(np.linalg.norm(final_embeddings-a, axis=1))
    print(",".join([reverse_dictionary[a] for a in diff[:10] if a not in [a, b, c]]))
